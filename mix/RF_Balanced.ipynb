# %%
import pandas as pd

df = pd.read_csv('../mix_balanced.csv', sep=';')
df.head()
# Out:
#    score                                            content    label
# 0    5.0  Thank you aplikasinya ga cuma cari loker aja c...  positif
# 1    1.0                    Aplikasi ga jelass, bikin ribet  negatif
# 2    5.0  App yang bagus untuk pencari peluang dan ilmu ...  positif
# 3    1.0  Setiap buka aplikasi LinkedIn langsung keluar ...  negatif
# 4    1.0  Linked bukan menyediakan info lowongan kerja t...  negatif

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hitung jumlah masing-masing label
label_counts = df['label'].value_counts()

# Buat grafik batang
ax = label_counts.plot(kind='bar', color='skyblue')

# Tambahkan jumlah di atas setiap batang
for i in ax.containers:
    ax.bar_label(i)

plt.title('Distribusi Label Sentimen')
plt.xlabel('Label')
plt.ylabel('Jumlah Ulasan')
plt.show()

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
import json

# %%
# Inisialisasi stemmer bahasa Indonesia dari Sastrawi    
factory = StemmerFactory()    
stemmer = factory.create_stemmer()    

# Muat daftar stopwords dari file    
with open('../stopwords.txt', 'r', encoding='utf-8') as file:    
    stopwords_id = set(file.read().splitlines())    

# Muat kamus slang dari file    
with open('../slang_words.txt', 'r', encoding='utf-8') as file:    
    slang_dict = json.load(file)    

# Fungsi untuk membersihkan teks    
def clean_text(text):    
    if not isinstance(text, str):  # Cek jika 'text' bukan string    
        return ""  # Mengembalikan string kosong jika 'text' bukan string    
    text = re.sub(r'\d+', '', text)  # Menghapus angka dari teks    
    # Menghapus tanda baca dan menambahkan spasi  
    text = re.sub(r'[^\w\s]', ' ', text)    
    text = re.sub(r'\s+', ' ', text)  # Menghapus spasi berlebih    
    text = text.strip()  # Menghapus spasi di awal dan akhir teks    
    text = text.lower()  # Mengubah semua huruf menjadi huruf kecil    
    text = re.sub(r'[^\x00-\x7F]+', '', text)  # Menghapus karakter non-ASCII    
    return text  # Mengembalikan teks yang telah dibersihkan    

# Fungsi untuk normalisasi slang    
def normalize_slang(text):    
    tokens = text.split()  # Memisahkan teks menjadi token    
    normalized_tokens = [slang_dict.get(token, token) for token in tokens]  # Normalisasi slang    
    return ' '.join(normalized_tokens)  # Menggabungkan kembali token menjadi string    

# Fungsi untuk tokenisasi    
def tokenize_text(text):    
    return word_tokenize(text)  # Menggunakan NLTK untuk tokenisasi    

# Fungsi untuk menghapus stopwords    
def remove_stopwords(tokens):    
    return [word for word in tokens if word not in stopwords_id]  # Menghapus stopwords dari token    

# Fungsi untuk stemming    
def stemming_tokens(tokens):    
    return [stemmer.stem(token) for token in tokens]  # Melakukan stemming pada token    

# Terapkan pembersihan teks    
df['cleaned_review'] = df['content'].apply(clean_text)    
# Normalisasi slang    
df['normalized_review'] = df['cleaned_review'].apply(normalize_slang)    
# Tokenisasi    
df['tokens'] = df['normalized_review'].apply(tokenize_text)    
# Hapus stopwords    
df['filtered_tokens'] = df['tokens'].apply(remove_stopwords)    
# Lakukan stemming pada token yang telah difilter    
df['stemmed_tokens'] = df['filtered_tokens'].apply(stemming_tokens)    
# Gabungkan token yang telah di-stem menjadi satu string    
df['stemmed_review'] = df['stemmed_tokens'].apply(lambda tokens: ' '.join(tokens))    
# Hapus baris yang mengandung NaN    
df_clean = df.dropna()    

# Simpan data yang telah diproses    
df_clean.to_csv('preprocessed_data.csv', index=False)

# %%
# Load preprocessed data
preprocessed_df = pd.read_csv('preprocessed_data.csv')

# %%
from IPython.display import display    

# Atur opsi tampilan pandas untuk menampilkan seluruh teks dan baris    
pd.set_option('display.max_colwidth', None)  # Tidak membatasi lebar kolom    
pd.set_option('display.max_rows', None)      # Menampilkan seluruh baris    

# Tampilkan beberapa baris dari DataFrame yang sudah diproses    
display(preprocessed_df[['content', 'cleaned_review', 'normalized_review', 'tokens', 'filtered_tokens', 'stemmed_tokens', 'stemmed_review']].head(10))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             content  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                        Thank you aplikasinya ga cuma cari loker aja cuma buka relasi lebih luas. ðŸ˜ŠðŸ‘ðŸ‘ðŸ‘
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Aplikasi ga jelass, bikin ribet
# 2                                                                                                                                                                                                                                                                                                                                                                                                  App yang bagus untuk pencari peluang dan ilmu Pokoknya good ðŸ‘banyak wawasan pengetahuan dari para profesional
# 3                                                                                                                                                                                                                                                                                                                                                                                                                Setiap buka aplikasi LinkedIn langsung keluar lagi buka lagi aplikasi nya keluar lagi kesel banget
# 4                                                                                                                                                                                                                                                                                                    Linked bukan menyediakan info lowongan kerja tapi linked kebanyakan menyediakan info jualan iklan produk perusahan ,pengaturan aflikasi kamu ini rumit ribet tak praktis tak simpel tak banyak aturan ðŸ˜ŽðŸ‘Ž
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Mau lihat dulu fungsi aplikasinya
# 6                                                                                                                                                                                                                                                                                                                                                                    App berhenti / menutup paksa ketika menekan tombol untuk halaman "posting" di sticky footer. Saya akan tingkatkan bintang setika ini teratasi.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Fungsionalitasnya memadai
# 8  Terima kasih telah banyak membantu orang mencari pekerjaan. Tapi kenapa melamar di linkedln selalu terdapat pihak pihak yg tidak bertanggung jawab . Yg merespon lamaran lamaran yg kita kirimkan. dengan modus penipuan. Mohon pihak linkedln perketat lagi lamaran lamaran pekerjaan yang kami kirimkan. Sehingga pihak pihak yg tidak bertanggung jawab. Bisa membalas lamaran kami dengan modus terima pekerjaan tetapi berkedok penipuan semua. Waspadalah hati hati untuk melamar di aplikasi ini. Makasih
# 9                                                                                                                                                                                                                                                                                                                               Lowongan yg di tawarkan banyak tp ya itu.. Harus pindah lagi ke aplikasi lain.. Jadi ya ngak ngaruh dong kita buat cv di linkedin ini... Kalau bisa kedepanya.. Tinggal share aja..
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             cleaned_review  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                             thank you aplikasinya ga cuma cari loker aja cuma buka relasi lebih luas
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                           aplikasi ga jelass bikin ribet
# 2                                                                                                                                                                                                                                                                                                                                                                                            app yang bagus untuk pencari peluang dan ilmu pokoknya good  banyak wawasan pengetahuan dari para profesional
# 3                                                                                                                                                                                                                                                                                                                                                                                                       setiap buka aplikasi linkedin langsung keluar lagi buka lagi aplikasi nya keluar lagi kesel banget
# 4                                                                                                                                                                                                                                                                                                  linked bukan menyediakan info lowongan kerja tapi linked kebanyakan menyediakan info jualan iklan produk perusahan pengaturan aflikasi kamu ini rumit ribet tak praktis tak simpel tak banyak aturan
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                        mau lihat dulu fungsi aplikasinya
# 6                                                                                                                                                                                                                                                                                                                                                                 app berhenti menutup paksa ketika menekan tombol untuk halaman posting di sticky footer saya akan tingkatkan bintang setika ini teratasi
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                fungsionalitasnya memadai
# 8  terima kasih telah banyak membantu orang mencari pekerjaan tapi kenapa melamar di linkedln selalu terdapat pihak pihak yg tidak bertanggung jawab yg merespon lamaran lamaran yg kita kirimkan dengan modus penipuan mohon pihak linkedln perketat lagi lamaran lamaran pekerjaan yang kami kirimkan sehingga pihak pihak yg tidak bertanggung jawab bisa membalas lamaran kami dengan modus terima pekerjaan tetapi berkedok penipuan semua waspadalah hati hati untuk melamar di aplikasi ini makasih
# 9                                                                                                                                                                                                                                                                                                                                 lowongan yg di tawarkan banyak tp ya itu harus pindah lagi ke aplikasi lain jadi ya ngak ngaruh dong kita buat cv di linkedin ini kalau bisa kedepanya tinggal share aja
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      normalized_review  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                         thank you aplikasinya tidak cuma cari loker saja cuma buka relasi lebih luas
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    aplikasi tidak jelass bikin ribet
# 2                                                                                                                                                                                                                                                                                                                                                                                                         app yang bagus untuk pencari peluang dan ilmu pokoknya good banyak wawasan pengetahuan dari para profesional
# 3                                                                                                                                                                                                                                                                                                                                                                                                                   setiap buka aplikasi linkedin langsung keluar lagi buka lagi aplikasi nya keluar lagi kesel banget
# 4                                                                                                                                                                                                                                                                                               linked bukan menyediakan informasi lowongan kerja tetapi linked kebanyakan menyediakan informasi jualan iklan produk perusahan pengaturan aflikasi kamu ini rumit ribet tidak praktis tidak simpel tidak banyak aturan
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    mau lihat dulu fungsi aplikasinya
# 6                                                                                                                                                                                                                                                                                                                                                                             app berhenti menutup paksa ketika menekan tombol untuk halaman posting di sticky footer saya akan tingkatkan bintang setika ini teratasi
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            fungsionalitasnya memadai
# 8  terima kasih telah banyak membantu orang mencari pekerjaan tetapi kenapa melamar di linkedln selalu terdapat pihak pihak yang tidak bertanggung jawab yang merespon lamaran lamaran yang kita kirimkan dengan modus penipuan mohon pihak linkedln perketat lagi lamaran lamaran pekerjaan yang kami kirimkan sehingga pihak pihak yang tidak bertanggung jawab bisa membalas lamaran kami dengan modus terima pekerjaan tetapi berkedok penipuan semua waspada hati hati untuk melamar di aplikasi ini terima kasih
# 9                                                                                                                                                                                                                                                                                                                                lowongan yang di tawarkan banyak tapi iya itu harus pindah lagi ke aplikasi lain jadi iya tidak berpengaruh dong kita buat cv di linkedin ini kalau bisa kedepanya tinggal share saja
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       tokens  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['thank', 'you', 'aplikasinya', 'tidak', 'cuma', 'cari', 'loker', 'saja', 'cuma', 'buka', 'relasi', 'lebih', 'luas']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['aplikasi', 'tidak', 'jelass', 'bikin', 'ribet']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ['app', 'yang', 'bagus', 'untuk', 'pencari', 'peluang', 'dan', 'ilmu', 'pokoknya', 'good', 'banyak', 'wawasan', 'pengetahuan', 'dari', 'para', 'profesional']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['setiap', 'buka', 'aplikasi', 'linkedin', 'langsung', 'keluar', 'lagi', 'buka', 'lagi', 'aplikasi', 'nya', 'keluar', 'lagi', 'kesel', 'banget']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                ['linked', 'bukan', 'menyediakan', 'informasi', 'lowongan', 'kerja', 'tetapi', 'linked', 'kebanyakan', 'menyediakan', 'informasi', 'jualan', 'iklan', 'produk', 'perusahan', 'pengaturan', 'aflikasi', 'kamu', 'ini', 'rumit', 'ribet', 'tidak', 'praktis', 'tidak', 'simpel', 'tidak', 'banyak', 'aturan']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['mau', 'lihat', 'dulu', 'fungsi', 'aplikasinya']
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['app', 'berhenti', 'menutup', 'paksa', 'ketika', 'menekan', 'tombol', 'untuk', 'halaman', 'posting', 'di', 'sticky', 'footer', 'saya', 'akan', 'tingkatkan', 'bintang', 'setika', 'ini', 'teratasi']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['fungsionalitasnya', 'memadai']
# 8  ['terima', 'kasih', 'telah', 'banyak', 'membantu', 'orang', 'mencari', 'pekerjaan', 'tetapi', 'kenapa', 'melamar', 'di', 'linkedln', 'selalu', 'terdapat', 'pihak', 'pihak', 'yang', 'tidak', 'bertanggung', 'jawab', 'yang', 'merespon', 'lamaran', 'lamaran', 'yang', 'kita', 'kirimkan', 'dengan', 'modus', 'penipuan', 'mohon', 'pihak', 'linkedln', 'perketat', 'lagi', 'lamaran', 'lamaran', 'pekerjaan', 'yang', 'kami', 'kirimkan', 'sehingga', 'pihak', 'pihak', 'yang', 'tidak', 'bertanggung', 'jawab', 'bisa', 'membalas', 'lamaran', 'kami', 'dengan', 'modus', 'terima', 'pekerjaan', 'tetapi', 'berkedok', 'penipuan', 'semua', 'waspada', 'hati', 'hati', 'untuk', 'melamar', 'di', 'aplikasi', 'ini', 'terima', 'kasih']
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['lowongan', 'yang', 'di', 'tawarkan', 'banyak', 'tapi', 'iya', 'itu', 'harus', 'pindah', 'lagi', 'ke', 'aplikasi', 'lain', 'jadi', 'iya', 'tidak', 'berpengaruh', 'dong', 'kita', 'buat', 'cv', 'di', 'linkedin', 'ini', 'kalau', 'bisa', 'kedepanya', 'tinggal', 'share', 'saja']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                filtered_tokens  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                        ['thank', 'you', 'tidak', 'cuma', 'loker', 'cuma', 'buka', 'relasi', 'lebih', 'luas']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['tidak', 'jelass', 'ribet']
# 2                                                                                                                                                                                                                                                                                                                                                                                  ['bagus', 'peluang', 'ilmu', 'pokoknya', 'good', 'banyak', 'wawasan', 'pengetahuan', 'para', 'profesional']
# 3                                                                                                                                                                                                                                                                                                                                                                                                  ['buka', 'langsung', 'keluar', 'lagi', 'buka', 'lagi', 'keluar', 'lagi', 'kesel', 'banget']
# 4                                                                                                                                                                                                                                                            ['menyediakan', 'informasi', 'tetapi', 'kebanyakan', 'menyediakan', 'informasi', 'jualan', 'produk', 'perusahan', 'pengaturan', 'aflikasi', 'rumit', 'ribet', 'tidak', 'praktis', 'tidak', 'simpel', 'tidak', 'banyak', 'aturan']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['mau', 'lihat', 'dulu', 'fungsi']
# 6                                                                                                                                                                                                                                                                                                                             ['berhenti', 'menutup', 'paksa', 'ketika', 'menekan', 'tombol', 'halaman', 'posting', 'sticky', 'footer', 'akan', 'tingkatkan', 'bintang', 'setika', 'teratasi']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['fungsionalitasnya', 'memadai']
# 8  ['terima', 'kasih', 'telah', 'banyak', 'membantu', 'orang', 'tetapi', 'kenapa', 'melamar', 'linkedln', 'selalu', 'terdapat', 'pihak', 'pihak', 'tidak', 'bertanggung', 'jawab', 'merespon', 'kirimkan', 'modus', 'penipuan', 'mohon', 'pihak', 'linkedln', 'perketat', 'lagi', 'kirimkan', 'sehingga', 'pihak', 'pihak', 'tidak', 'bertanggung', 'jawab', 'bisa', 'membalas', 'modus', 'terima', 'tetapi', 'berkedok', 'penipuan', 'waspada', 'hati', 'hati', 'melamar', 'terima', 'kasih']
# 9                                                                                                                                                                                                                                                                                                                                            ['tawarkan', 'banyak', 'tapi', 'harus', 'pindah', 'lagi', 'lain', 'tidak', 'berpengaruh', 'cv', 'kalau', 'bisa', 'kedepanya', 'tinggal', 'share']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                          stemmed_tokens  \
# 0                                                                                                                                                                                                                                                                                                                                                                 ['thank', 'you', 'tidak', 'cuma', 'loker', 'cuma', 'buka', 'relasi', 'lebih', 'luas']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                          ['tidak', 'jelass', 'ribet']
# 2                                                                                                                                                                                                                                                                                                                                                       ['bagus', 'peluang', 'ilmu', 'pokok', 'good', 'banyak', 'wawas', 'tahu', 'para', 'profesional']
# 3                                                                                                                                                                                                                                                                                                                                                           ['buka', 'langsung', 'keluar', 'lagi', 'buka', 'lagi', 'keluar', 'lagi', 'kesel', 'banget']
# 4                                                                                                                                                                                                                                                    ['sedia', 'informasi', 'tetapi', 'banyak', 'sedia', 'informasi', 'jual', 'produk', 'usah', 'atur', 'aflikasi', 'rumit', 'ribet', 'tidak', 'praktis', 'tidak', 'simpel', 'tidak', 'banyak', 'atur']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                    ['mau', 'lihat', 'dulu', 'fungsi']
# 6                                                                                                                                                                                                                                                                                                      ['henti', 'tutup', 'paksa', 'ketika', 'tekan', 'tombol', 'halaman', 'posting', 'sticky', 'footer', 'akan', 'tingkat', 'bintang', 'tika', 'atas']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                            ['fungsionalitas', 'pada']
# 8  ['terima', 'kasih', 'telah', 'banyak', 'bantu', 'orang', 'tetapi', 'kenapa', 'lamar', 'linkedln', 'selalu', 'dapat', 'pihak', 'pihak', 'tidak', 'tanggung', 'jawab', 'merespon', 'kirim', 'modus', 'tipu', 'mohon', 'pihak', 'linkedln', 'ketat', 'lagi', 'kirim', 'sehingga', 'pihak', 'pihak', 'tidak', 'tanggung', 'jawab', 'bisa', 'balas', 'modus', 'terima', 'tetapi', 'kedok', 'tipu', 'waspada', 'hati', 'hati', 'lamar', 'terima', 'kasih']
# 9                                                                                                                                                                                                                                                                                                                ['tawar', 'banyak', 'tapi', 'harus', 'pindah', 'lagi', 'lain', 'tidak', 'pengaruh', 'cv', 'kalau', 'bisa', 'depa', 'tinggal', 'share']
#
#                                                                                                                                                                                                                                                                                               stemmed_review
# 0                                                                                                                                                                                                                                                     thank you tidak cuma loker cuma buka relasi lebih luas
# 1                                                                                                                                                                                                                                                                                         tidak jelass ribet
# 2                                                                                                                                                                                                                                           bagus peluang ilmu pokok good banyak wawas tahu para profesional
# 3                                                                                                                                                                                                                                               buka langsung keluar lagi buka lagi keluar lagi kesel banget
# 4                                                                                                                                                                      sedia informasi tetapi banyak sedia informasi jual produk usah atur aflikasi rumit ribet tidak praktis tidak simpel tidak banyak atur
# 5                                                                                                                                                                                                                                                                                      mau lihat dulu fungsi
# 6                                                                                                                                                                                                         henti tutup paksa ketika tekan tombol halaman posting sticky footer akan tingkat bintang tika atas
# 7                                                                                                                                                                                                                                                                                        fungsionalitas pada
# 8  terima kasih telah banyak bantu orang tetapi kenapa lamar linkedln selalu dapat pihak pihak tidak tanggung jawab merespon kirim modus tipu mohon pihak linkedln ketat lagi kirim sehingga pihak pihak tidak tanggung jawab bisa balas modus terima tetapi kedok tipu waspada hati hati lamar terima kasih
# 9                                                                                                                                                                                                                   tawar banyak tapi harus pindah lagi lain tidak pengaruh cv kalau bisa depa tinggal share

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.model_selection import train_test_split  
import numpy as np  
import pandas as pd  
import seaborn as sns  
import matplotlib.pyplot as plt  

# Misalkan preprocessed_df adalah DataFrame Anda dengan kolom 'stemmed_review' dan 'label'  

# Split data menjadi training dan testing  
X_train, X_test, y_train, y_test = train_test_split(  
    preprocessed_df['stemmed_review'], preprocessed_df['label'], test_size=0.2, random_state=42  
)  

# Inisialisasi TF-IDF Vectorizer  
tfidf_vectorizer = TfidfVectorizer(  
    max_features=500,  # Anda dapat menyesuaikan jumlah fitur  
    ngram_range=(1, 2),  # Menggunakan unigram dan bigram  
)  

# Fit dan transform data training  
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)  

# Transform data testing  
X_test_tfidf = tfidf_vectorizer.transform(X_test)  

# Konversi sparse matrix ke DataFrame  
tfidf_df = pd.DataFrame(X_train_tfidf.toarray(), columns=tfidf_vectorizer.get_feature_names_out())  

# Tambahkan kolom untuk dokumen  
tfidf_df['Document'] = [f'Document {i}' for i in range(tfidf_df.shape[0])]  
tfidf_df.set_index('Document', inplace=True)  

# Hitung rata-rata skor TF-IDF untuk setiap kata  
tfidf_means = tfidf_df.mean(axis=0)  

# Ambil 5 kata dengan skor TF-IDF tertinggi  
top_words = tfidf_means.nlargest(5).index  
tfidf_df_subset = tfidf_df[top_words].head(10)  # Ambil hanya 10 baris  

# Buat heatmap untuk 5 kata teratas  
plt.figure(figsize=(12, 8))  
sns.heatmap(tfidf_df_subset, annot=True, cmap='Blues', cbar_kws={'label': 'Bobot TF-IDF'})  
plt.title('Visualisasi Bobot TF-IDF')  
plt.xlabel('Kata')  
plt.ylabel('Dokumen')  
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.show()

# %%
# import joblib

# # Simpan TfidfVectorizer ke file
# joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.joblib')

# print("TfidfVectorizer telah disimpan.")

# %%
import numpy as np  
import pandas as pd  
from sklearn.ensemble import RandomForestClassifier  
from sklearn.model_selection import cross_val_score, KFold    

# Model Extra Trees  
model = RandomForestClassifier(class_weight='balanced')  

# Inisialisasi KFold    
kf = KFold(n_splits=5, shuffle=True, random_state=42)    

# Terapkan cross-validation    
cv_scores = cross_val_score(model, X_train_tfidf, y_train, cv=kf)    

# Tampilkan hasil cross-validation dalam bentuk tabel  
cv_results = pd.DataFrame({  
    'Fold': range(1, len(cv_scores) + 1),  # Menggunakan range untuk nomor fold  
    'Score': cv_scores  
})  

# Menambahkan kolom untuk rata-rata  
mean_score = np.mean(cv_scores)  # Hitung rata-rata dari skor  
cv_results.loc[len(cv_results)] = ['Mean', mean_score]  # Tambahkan baris rata-rata  

# Tampilkan hasil cross-validation  
print(cv_results)
# Out:
#    Fold     Score
# 0     1  0.878019
# 1     2  0.887545
# 2     3  0.887545
# 3     4  0.883918
# 4     5  0.896010
# 5  Mean  0.886607

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Fitting model pada data pelatihan
model.fit(X_train_tfidf, y_train)

# Prediksi pada data testing (gunakan representasi TF-IDF dari data testing)
y_pred = model.predict(X_test_tfidf)

# Evaluasi model dengan classification report
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)

# Visualisasi confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      negatif       0.94      0.90      0.92       329
#       netral       0.88      0.96      0.92       342
#      positif       0.95      0.90      0.92       363
#
#     accuracy                           0.92      1034
#    macro avg       0.92      0.92      0.92      1034
# weighted avg       0.92      0.92      0.92      1034

# %%
import joblib

# Save the model to a file
joblib.dump(model, 'random_forest_model.joblib')

# To load the model later:
# model = joblib.load('extra_trees_model.joblib')
# Out:
# ['random_forest_model.joblib']

# %%
# Simpan ulasan asli dari X_test ke dalam variabel
original_reviews = df.loc[X_test.index, 'content']

# Membuat DataFrame dari hasil prediksi
df_results = pd.DataFrame({
    'Review Asli': original_reviews,  # Menggunakan teks ulasan asli
    'Label Asli': y_test,             # Label asli
    'Prediksi': y_pred                # Label yang diprediksi oleh model
})

# Filter untuk data yang salah diprediksi
df_misclassified = df_results[df_results['Label Asli'] != df_results['Prediksi']]

# Tampilkan data yang salah diprediksi dalam bentuk tabel
print("Data yang salah diprediksi:")
display(df_misclassified)  # Menggunakan display untuk tabel interaktif
# Out:
# Data yang salah diprediksi:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Review Asli  \
# 1988                                                                                                                                                                                                                                                                                                                                                                                                                                     Apakah tidak ada bahasa indonesia nya apa saat di home. Selalu bahasa english
# 1235                                                                                                                                                                                                                                                          terimakasih linkedin sudah memberikan saya kesempatan mendapatkan pekerjaan 10 bulan lalu, orang2 di linkedin juga seru2 kok, dan gapernah kecewa sama aplikasi ini selama pemakaian. jd aplikasi pertama yg sering saya buka dan schroll setiap harinya
# 1662                                                                                                                                                                                                                                                                                                                                                                                                                               semoga terbantu dengan adanya aplikasi ini untuk yang sedang membutuhkan pekerjaan.
# 3977                                                                                                                                                                      Sebetulnya bagus dan sangat membantu aplikasinya.. Tapi sngt disayangkan dan hny sekedar formalitas saja untuk perusahaan2 menginklankan di jobstreet. Sudah banyak melamar2 di jobstreet tapi dari perusahaan yang saya apply tidak pernah di lihat / di respon lamaran2nya sampai batas pembukaan lamaran di tutup.....#indonesiacemas2045
# 3414                                                                                                                                                                                                                                                      cara lamarnya mudah dan tentunya gratis. saya suka. tidak seperti aplikasi yang lain yang harus berbayar. terimakasih sudah membuat aplikasi ini. saya harap aplikasi ini tidak memiliki fitur pro hanya untuk pemakai membayar aplikasi agar bisa di pakai.
# 279                                                                                                                                                                                                                                                                                                                                                                                                                                               Saya suka saya suka tapi penggunanya 30 mb yah biar hemat kuota data
# 2985                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                                                                                                                                                                                                          tinggal nunggu panggilan
# 3179                                                                                                                                                                                                                                                                                                                                                                                                                                                     smentara sya kasih bintang3 , karena belum ada respon satupun
# 2680                                                                                                                                                                                                                                                                                                        sudah sering saya cari info lowongan di aplikasi manapun belum ada yang sesuai,tapi di indeed saya bisa menemukan pekerjaan sesuai dengan bidang saya... terima kasih indeed...Ã°Å¸â„¢ÂÃ°Å¸â„¢ÂÃ°Å¸â„¢Â
# 2841                                                                                                                                                                                                                                                                                                                                                                                                                                                                            semoga info loker yg ada benar2 update
# 3733                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Belom ada pencerahan dapat kerjaan
# 1448                                                                                                                                                                                                                                                                                                                                                                                                                                                                       beberapa lowongan dicurigai sebagai pialang
# 1047                                                                                                                                                                                                                                                                                                                                                                                                                                    aku belum masuk berkerja LinkedIn masuk sekolah aku di Banyuwangi selatan mbak
# 1323                                                                                                                                                                                                                                                                                                                                                                                     The best aplikasi bikin minder hahaha keren relasi di aplikasi ini sumpah bikin minder tapi memotivasi untuk mengupgrade diri
# 2689                                                                                                                                                                                                                      aplikasinya sangat membantu karena terlalu perhatian, saat di panggilan interview, di tolak selalu di beri tahu dan jika tidak di hubungi akan d review lagi... ini paling bagus banget deh...dan tolong di filter lagi untuk perusahaan yang tidak jelas agar tidak mendaftar. terima kasih
#
#      Label Asli Prediksi
# 1988     netral  negatif
# 1235    positif  negatif
# 1662     netral  positif
# 3977    negatif   netral
# 3414    positif   netral
# 279     positif   netral
# 2985    positif   netral
# 239     negatif  positif
# 2858    positif  negatif
# 1870    negatif  positif
# 4255     netral  negatif
# 879     positif   netral
# 3491    negatif   netral
# 29      positif   netral
# 3153    negatif  positif
# 1813    negatif  positif
# 1034    positif  negatif
# 1504    negatif  positif
# 3213    negatif   netral
# 764     positif  negatif
# 471     positif   netral
# 2633    positif  negatif
# 1231    positif  negatif
# 3048    positif   netral
# 1281    positif  negatif
# 1665    positif   netral
# 4408     netral  positif
# 2059    negatif   netral
# 3661     netral  negatif
# 1405     netral  positif
# 3921     netral  negatif
# 3204    negatif   netral
# 3968    negatif   netral
# 653      netral  positif
# 2229    negatif   netral
# 4023     netral  negatif
# 1427     netral  positif
# 69      negatif   netral
# 221     negatif   netral
# 3909    negatif   netral
# 2103     netral  negatif
# 3109    positif   netral
# 3804    negatif   netral
# 210     positif   netral
# 1983    negatif  positif
# 478     positif   netral
# 5145     netral  negatif
# 1905    negatif  positif
# 2107    positif  negatif
# 2121     netral  positif
# 1212    positif   netral
# 3961    negatif   netral
# 3518    positif  negatif
# 2519    positif   netral
# 3934    negatif   netral
# 751     negatif  positif
# 1149    positif   netral
# 3382    positif  negatif
# 1340    positif   netral
# 1583    positif   netral
# 3270    negatif   netral
# 969     positif   netral
# 3433     netral  negatif
# 1543    positif   netral
# 3626    positif  negatif
# 3520    positif   netral
# 2276    negatif  positif
# 3595    positif   netral
# 2394    negatif   netral
# 3032    negatif   netral
# 1557    negatif   netral
# 720     negatif  positif
# 3316    positif   netral
# 3710    negatif  positif
# 1532     netral  positif
# 3179    negatif   netral
# 2680    positif   netral
# 2841    positif   netral
# 3733    negatif   netral
# 1448    negatif   netral
# 1047    negatif   netral
# 1323    positif   netral
# 2689    positif  negatif
